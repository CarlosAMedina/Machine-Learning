# %%
#El individuo perfecto - Práctica 2 - Machine Learning
#Medina Ascencio Carlos Armando

import random
import math

# --- Configuración ---
NUM_GENES = 20
VALOR_MIN = 1
VALOR_MAX = 9
PAREJAS_POR_GRUPO = 10
INDIVIDUOS_POR_GRUPO = PAREJAS_POR_GRUPO * 2
NUM_GRUPOS = 5
MUTACION_PROB = 0.1
FREC_MIGRACION = 5   # cada cuántas generaciones migran
NUM_MIGRANTES = 9    # individuos que migran por subgrupo

# --- Funciones básicas ---
def crear_individuo():
    return [random.randint(VALOR_MIN, VALOR_MAX) for _ in range(NUM_GENES)]

def crear_grupo():
    return [crear_individuo() for _ in range(INDIVIDUOS_POR_GRUPO)]

def cruzar(padre, madre):
    hijo1, hijo2 = [], []
    for p, m in zip(padre, madre):
        prom = (p + m) / 2
        hijo1.append(math.floor(prom))
        hijo2.append(math.ceil(prom))
    return hijo1, hijo2

def mutar(individuo):
    for i in range(len(individuo)):
        if random.random() < MUTACION_PROB:
            cambio = 1 if random.random() < 0.5 else -1
            individuo[i] = min(max(individuo[i] + cambio, VALOR_MIN), VALOR_MAX)
    return individuo

def es_perfecto(individuo):
    return all(g >= 9 for g in individuo)

def fitness(individuo):
    """Medimos cuán cercano está al ser perfecto (suma de genes)."""
    return sum(individuo)

# --- Selección de migrantes ---
def seleccionar_migrantes(grupo):
    migrantes = []
    for _ in range(NUM_MIGRANTES):
        candidatos = random.sample(grupo, 3)  # torneo de 3
        mejor = max(candidatos, key=fitness)
        migrantes.append(mejor[:])  # copia
    return migrantes

# --- Reemplazar peores ---
def reemplazar_peores(grupo, migrantes):
    grupo.sort(key=fitness)  # ordenamos de peor a mejor
    for i in range(len(migrantes)):
        grupo[i] = migrantes[i]  # reemplaza peores
    return grupo

# --- Evolución por grupo ---
def evolucionar_grupo(grupo):
    nueva_gen = []
    random.shuffle(grupo)
    for i in range(0, len(grupo), 2):
        padre, madre = grupo[i], grupo[i+1]
        hijo1, hijo2 = cruzar(padre, madre)
        nueva_gen.append(mutar(hijo1))
        nueva_gen.append(mutar(hijo2))
    return nueva_gen

# --- Evolución total ---
def evolucionar():
    grupos = [crear_grupo() for _ in range(NUM_GRUPOS)]
    generacion = 0

    while True:
        generacion += 1

        # evolucionamos cada grupo de forma independiente
        for g in range(NUM_GRUPOS):
            grupos[g] = evolucionar_grupo(grupos[g])

        # migración cada FREC_MIGRACION generaciones
        if generacion % FREC_MIGRACION == 0:
            migrantes_por_grupo = [seleccionar_migrantes(grupo) for grupo in grupos]
            # rotar migrantes (grupo i manda a grupo (i+1)%NUM_GRUPOS)
            for i in range(NUM_GRUPOS):
                destino = (i + 1) % NUM_GRUPOS
                grupos[destino] = reemplazar_peores(grupos[destino], migrantes_por_grupo[i])

        # evaluar mejor individuo global
        mejor_global = max((ind for grupo in grupos for ind in grupo), key=fitness)

        print(f"Generación {generacion} | Mejor fitness: {fitness(mejor_global)} | Mejor individuo: {mejor_global}")

        if es_perfecto(mejor_global):
            print(f"\n¡Ser perfecto encontrado en la generación {generacion}!")
            print(mejor_global)
            return mejor_global, generacion

# --- Ejecutar ---
if __name__ == "__main__":
    evolucionar()
# Out:
# Generación 1 | Mejor fitness: 119 | Mejor individuo: [7, 8, 8, 7, 7, 7, 5, 6, 5, 5, 5, 5, 5, 5, 5, 4, 8, 6, 5, 6]
# Generación 2 | Mejor fitness: 120 | Mejor individuo: [7, 6, 6, 6, 6, 7, 3, 5, 5, 6, 7, 6, 4, 5, 6, 8, 7, 8, 7, 5]
# Generación 3 | Mejor fitness: 120 | Mejor individuo: [6, 6, 5, 2, 4, 7, 7, 6, 8, 6, 5, 4, 5, 6, 7, 6, 6, 8, 8, 8]
# Generación 4 | Mejor fitness: 123 | Mejor individuo: [7, 6, 6, 4, 5, 6, 5, 7, 7, 6, 5, 5, 5, 5, 9, 7, 6, 8, 7, 7]
# Generación 5 | Mejor fitness: 120 | Mejor individuo: [5, 6, 6, 7, 6, 7, 7, 6, 5, 8, 5, 5, 5, 7, 5, 6, 5, 7, 7, 5]
# Generación 6 | Mejor fitness: 123 | Mejor individuo: [5, 7, 6, 7, 6, 7, 7, 6, 5, 7, 5, 6, 7, 7, 5, 6, 5, 7, 7, 5]
# Generación 7 | Mejor fitness: 119 | Mejor individuo: [6, 6, 6, 7, 6, 7, 5, 7, 6, 5, 5, 5, 6, 7, 6, 5, 6, 6, 6, 6]
# Generación 8 | Mejor fitness: 121 | Mejor individuo: [5, 6, 6, 5, 4, 5, 6, 7, 7, 6, 6, 7, 6, 6, 6, 7, 6, 7, 6, 7]
# Generación 9 | Mejor fitness: 123 | Mejor individuo: [6, 7, 6, 5, 4, 6, 6, 6, 8, 6, 6, 6, 6, 6, 6, 7, 6, 7, 6, 7]
# Generación 10 | Mejor fitness: 119 | Mejor individuo: [5, 6, 6, 5, 5, 7, 6, 6, 6, 7, 5, 5, 5, 6, 6, 7, 5, 7, 7, 7]
# Generación 11 | Mejor fitness: 122 | Mejor individuo: [5, 6, 6, 6, 5, 6, 7, 5, 8, 6, 5, 6, 7, 6, 7, 8, 6, 6, 6, 5]
# Generación 12 | Mejor fitness: 125 | Mejor individuo: [6, 6, 6, 6, 5, 6, 6, 7, 7, 7, 6, 6, 6, 6, 6, 7, 5, 6, 8, 7]
# Generación 13 | Mejor fitness: 125 | Mejor individuo: [6, 6, 6, 6, 6, 6, 6, 5, 5, 7, 6, 6, 6, 6, 6, 7, 7, 8, 7, 7]
# Generación 14 | Mejor fitness: 126 | Mejor individuo: [6, 6, 6, 6, 6, 7, 7, 6, 5, 7, 6, 6, 6, 6, 7, 7, 6, 7, 7, 6]
# Generación 15 | Mejor fitness: 127 | Mejor individuo: [7, 6, 6, 7, 7, 8, 6, 7, 6, 6, 6, 6, 6, 6, 6, 6, 6, 7, 6, 6]
# Generación 16 | Mejor fitness: 132 | Mejor individuo: [7, 6, 6, 8, 7, 8, 7, 7, 6, 7, 6, 6, 6, 7, 6, 6, 6, 7, 7, 6]
# Generación 17 | Mejor fitness: 131 | Mejor individuo: [6, 7, 7, 7, 6, 7, 6, 7, 6, 7, 6, 7, 7, 6, 6, 7, 6, 7, 6, 7]
# Generación 18 | Mejor fitness: 135 | Mejor individuo: [7, 7, 7, 7, 6, 7, 6, 7, 6, 7, 6, 7, 7, 7, 7, 7, 6, 7, 7, 7]
# Generación 19 | Mejor fitness: 131 | Mejor individuo: [6, 6, 6, 6, 6, 6, 6, 7, 7, 9, 5, 7, 7, 6, 7, 7, 6, 7, 7, 7]
# Generación 20 | Mejor fitness: 131 | Mejor individuo: [6, 6, 6, 6, 6, 6, 6, 6, 7, 9, 6, 7, 7, 6, 7, 7, 6, 8, 6, 7]
# Generación 21 | Mejor fitness: 136 | Mejor individuo: [7, 7, 7, 6, 6, 6, 7, 8, 7, 7, 6, 6, 6, 7, 7, 7, 7, 8, 7, 7]
# Generación 22 | Mejor fitness: 134 | Mejor individuo: [6, 7, 7, 7, 7, 8, 6, 7, 7, 7, 7, 6, 6, 7, 6, 6, 6, 7, 7, 7]
# Generación 23 | Mejor fitness: 139 | Mejor individuo: [6, 7, 8, 8, 7, 8, 6, 7, 7, 7, 7, 6, 7, 7, 7, 7, 6, 7, 7, 7]
# Generación 24 | Mejor fitness: 140 | Mejor individuo: [8, 8, 7, 6, 7, 7, 7, 8, 6, 7, 6, 6, 6, 7, 8, 7, 8, 7, 7, 7]
# Generación 25 | Mejor fitness: 137 | Mejor individuo: [7, 7, 7, 7, 6, 7, 6, 7, 7, 8, 6, 6, 7, 7, 7, 7, 6, 8, 7, 7]
# Generación 26 | Mejor fitness: 138 | Mejor individuo: [7, 7, 7, 8, 6, 8, 6, 7, 6, 8, 6, 6, 7, 7, 7, 6, 7, 8, 7, 7]
# Generación 27 | Mejor fitness: 143 | Mejor individuo: [8, 7, 7, 7, 7, 7, 7, 6, 7, 7, 7, 7, 7, 8, 7, 8, 7, 8, 7, 7]
# Generación 28 | Mejor fitness: 140 | Mejor individuo: [7, 7, 7, 8, 6, 7, 6, 7, 5, 8, 8, 7, 7, 7, 8, 8, 6, 7, 7, 7]
# Generación 29 | Mejor fitness: 145 | Mejor individuo: [8, 7, 8, 7, 6, 7, 7, 8, 6, 9, 7, 6, 7, 7, 7, 7, 7, 8, 8, 8]
# Generación 30 | Mejor fitness: 141 | Mejor individuo: [7, 7, 7, 5, 7, 7, 8, 8, 6, 8, 6, 7, 7, 7, 7, 7, 7, 8, 7, 8]
# Generación 31 | Mejor fitness: 145 | Mejor individuo: [7, 7, 8, 8, 7, 8, 7, 7, 7, 6, 7, 6, 6, 8, 8, 7, 8, 7, 9, 7]
# Generación 32 | Mejor fitness: 147 | Mejor individuo: [8, 8, 7, 8, 7, 9, 7, 7, 8, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 8]
# Generación 33 | Mejor fitness: 146 | Mejor individuo: [8, 7, 8, 7, 7, 7, 7, 8, 7, 8, 7, 7, 7, 8, 7, 8, 7, 7, 7, 7]
# Generación 34 | Mejor fitness: 146 | Mejor individuo: [7, 6, 7, 7, 7, 7, 8, 9, 7, 8, 7, 7, 7, 7, 8, 7, 7, 7, 8, 8]
# Generación 35 | Mejor fitness: 146 | Mejor individuo: [7, 7, 7, 6, 6, 7, 8, 9, 6, 8, 6, 7, 8, 7, 8, 9, 7, 7, 8, 8]
# Generación 36 | Mejor fitness: 150 | Mejor individuo: [7, 7, 7, 7, 7, 8, 8, 8, 7, 8, 7, 7, 8, 7, 8, 8, 8, 7, 8, 8]
# Generación 37 | Mejor fitness: 152 | Mejor individuo: [7, 8, 8, 7, 7, 7, 8, 8, 7, 8, 6, 9, 8, 7, 8, 8, 7, 8, 8, 8]
# Generación 38 | Mejor fitness: 151 | Mejor individuo: [7, 7, 8, 7, 8, 9, 7, 8, 8, 7, 7, 7, 7, 7, 8, 8, 7, 7, 9, 8]
# Generación 39 | Mejor fitness: 153 | Mejor individuo: [8, 8, 8, 7, 7, 9, 7, 9, 8, 7, 7, 7, 8, 7, 8, 8, 8, 7, 7, 8]
# Generación 40 | Mejor fitness: 153 | Mejor individuo: [8, 8, 8, 8, 8, 8, 7, 8, 7, 7, 7, 7, 7, 8, 8, 8, 6, 8, 9, 8]
# Generación 41 | Mejor fitness: 156 | Mejor individuo: [8, 8, 8, 8, 8, 8, 6, 9, 9, 8, 7, 7, 7, 8, 8, 8, 6, 8, 9, 8]
# Generación 42 | Mejor fitness: 156 | Mejor individuo: [8, 8, 8, 8, 7, 9, 7, 8, 7, 8, 8, 7, 7, 8, 8, 8, 8, 8, 8, 8]
# Generación 43 | Mejor fitness: 157 | Mejor individuo: [8, 7, 7, 8, 8, 8, 7, 8, 8, 8, 8, 7, 7, 9, 8, 9, 7, 8, 9, 8]
# Generación 44 | Mejor fitness: 157 | Mejor individuo: [8, 8, 8, 7, 7, 8, 8, 8, 8, 9, 8, 8, 8, 7, 8, 8, 6, 8, 8, 9]
# Generación 45 | Mejor fitness: 159 | Mejor individuo: [8, 8, 8, 7, 7, 8, 8, 9, 8, 9, 8, 8, 8, 7, 8, 8, 7, 8, 8, 9]
# Generación 46 | Mejor fitness: 160 | Mejor individuo: [8, 8, 8, 7, 7, 8, 8, 8, 8, 9, 8, 8, 8, 8, 9, 8, 8, 8, 8, 8]
# Generación 47 | Mejor fitness: 164 | Mejor individuo: [8, 8, 8, 7, 8, 8, 8, 8, 8, 9, 8, 8, 9, 8, 9, 9, 9, 8, 8, 8]
# Generación 48 | Mejor fitness: 162 | Mejor individuo: [8, 8, 8, 7, 8, 8, 8, 7, 8, 9, 7, 8, 8, 8, 9, 9, 9, 9, 8, 8]
# Generación 49 | Mejor fitness: 165 | Mejor individuo: [8, 8, 8, 7, 8, 8, 9, 7, 8, 9, 8, 8, 8, 9, 9, 9, 8, 9, 9, 8]
# Generación 50 | Mejor fitness: 164 | Mejor individuo: [8, 9, 8, 7, 8, 8, 8, 8, 9, 9, 8, 8, 8, 8, 8, 8, 8, 9, 8, 9]
# Generación 51 | Mejor fitness: 167 | Mejor individuo: [7, 8, 8, 8, 8, 9, 9, 9, 8, 8, 9, 9, 8, 8, 9, 8, 8, 8, 9, 9]
# Generación 52 | Mejor fitness: 169 | Mejor individuo: [9, 8, 8, 8, 8, 9, 9, 8, 8, 9, 8, 9, 8, 8, 9, 9, 8, 8, 9, 9]
# Generación 53 | Mejor fitness: 169 | Mejor individuo: [9, 8, 9, 9, 7, 8, 8, 9, 8, 9, 9, 7, 9, 8, 9, 9, 8, 8, 9, 9]
# Generación 54 | Mejor fitness: 168 | Mejor individuo: [8, 7, 9, 9, 7, 8, 8, 9, 8, 9, 9, 7, 9, 8, 9, 9, 8, 9, 9, 9]
# Generación 55 | Mejor fitness: 169 | Mejor individuo: [9, 8, 9, 9, 8, 8, 7, 8, 9, 8, 8, 8, 8, 9, 9, 9, 9, 9, 9, 8]
# Generación 56 | Mejor fitness: 169 | Mejor individuo: [8, 9, 9, 8, 9, 9, 8, 8, 8, 9, 8, 8, 9, 9, 8, 9, 8, 7, 9, 9]
# Generación 57 | Mejor fitness: 171 | Mejor individuo: [9, 8, 8, 9, 9, 9, 8, 9, 8, 8, 8, 8, 9, 9, 9, 9, 9, 8, 8, 9]
# Generación 58 | Mejor fitness: 171 | Mejor individuo: [8, 9, 9, 8, 9, 9, 8, 8, 8, 9, 9, 9, 8, 9, 9, 8, 8, 8, 9, 9]
# Generación 59 | Mejor fitness: 172 | Mejor individuo: [9, 8, 9, 8, 8, 9, 9, 9, 9, 9, 8, 8, 9, 8, 8, 9, 8, 9, 9, 9]
# Generación 60 | Mejor fitness: 173 | Mejor individuo: [9, 8, 9, 8, 7, 9, 9, 8, 9, 9, 9, 9, 9, 9, 8, 9, 8, 9, 9, 9]
# Generación 61 | Mejor fitness: 174 | Mejor individuo: [9, 9, 9, 8, 8, 9, 9, 9, 9, 8, 9, 9, 9, 9, 7, 9, 8, 9, 9, 9]
# Generación 62 | Mejor fitness: 175 | Mejor individuo: [9, 9, 9, 9, 9, 8, 9, 8, 8, 9, 9, 9, 9, 9, 8, 9, 9, 8, 9, 9]
# Generación 63 | Mejor fitness: 175 | Mejor individuo: [9, 8, 9, 9, 8, 9, 9, 9, 9, 9, 9, 8, 9, 9, 9, 9, 8, 8, 9, 9]
# Generación 64 | Mejor fitness: 175 | Mejor individuo: [9, 9, 9, 8, 8, 9, 9, 9, 9, 9, 9, 8, 9, 8, 9, 9, 8, 9, 9, 9]
# Generación 65 | Mejor fitness: 175 | Mejor individuo: [9, 9, 9, 8, 8, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 8, 8, 8]
# Generación 66 | Mejor fitness: 178 | Mejor individuo: [9, 9, 9, 8, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 8, 9, 9]
# Generación 67 | Mejor fitness: 178 | Mejor individuo: [9, 9, 9, 8, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 8, 9, 9]
# Generación 68 | Mejor fitness: 178 | Mejor individuo: [9, 9, 9, 9, 8, 9, 9, 9, 9, 9, 9, 9, 8, 9, 9, 9, 9, 9, 9, 9]
# Generación 69 | Mejor fitness: 179 | Mejor individuo: [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 8, 9, 9]
# Generación 70 | Mejor fitness: 179 | Mejor individuo: [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 8, 9, 9]
# Generación 71 | Mejor fitness: 179 | Mejor individuo: [9, 9, 9, 8, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
# Generación 72 | Mejor fitness: 179 | Mejor individuo: [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 8, 9, 9, 9]
# Generación 73 | Mejor fitness: 179 | Mejor individuo: [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 8, 9, 9, 9]
# Generación 74 | Mejor fitness: 179 | Mejor individuo: [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 8, 9, 9, 9]
# Generación 75 | Mejor fitness: 178 | Mejor individuo: [9, 9, 9, 8, 9, 8, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
# Generación 76 | Mejor fitness: 180 | Mejor individuo: [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
#
# ¡Ser perfecto encontrado en la generación 76!
# [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
